# %% [markdown]
# # Evaluation using MobileNetV3 Large model

# %%
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.applications.resnet import ResNet50, ResNet101 , ResNet152
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, log_loss, jaccard_score
import numpy as np
import os
from PIL import Image
from shutil import copyfile  
import pandas as pd
import seaborn as sns
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # **Dataset Describtion**
# * train - 70%
# * test - 20%
# * validation - 10%

# %% [markdown]
# # Preprocess of the dataset

# %%
# Define the paths to our train, validation, and test datasets
train_data_dir =  '/Users/tony/Documents/research_projects/mult_colon/crc_fin_dataset/crc/crc_train'
test_data_dir = "/Users/tony/Documents/research_projects/mult_colon/crc_fin_dataset/crc/crc_test"
validation_data_dir = "/Users/tony/Documents/research_projects/mult_colon/crc_fin_dataset/crc/crc_val"

# Image dimensions
IMG_WIDTH, IMG_HEIGHT = 224, 224
input_shape = (IMG_WIDTH, IMG_HEIGHT, 3) # RGB images

# %% [markdown]
# # **Data generators**

# %%
# Data generators for RGB images

from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# test_datagen = ImageDataGenerator(rescale=1./255)
# validation_datagen = ImageDataGenerator(rescale=1./255)

validation_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
testa_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)



# Define data generators for RGB images with augmentation
train_datagen_augmented = ImageDataGenerator(
    #rescale=1./255,
    preprocessing_function = preprocess_input,
    rotation_range=20,  # Rotation angle range
    width_shift_range=0.2,  # Horizontal shift range
    height_shift_range=0.2,  # Vertical shift range
    shear_range=0.2,  # Shear intensity
    zoom_range=0.2,  # Random zoom range
    horizontal_flip=True,  # Randomly flip images horizontally
    vertical_flip=False,  # Do not flip images vertically
    fill_mode='nearest'  # Fill mode for newly created pixels
)

# Generate augmented data for training
train_generator = train_datagen_augmented.flow_from_directory(
    train_data_dir,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=8,
    class_mode='categorical'
  
)
val_datagen = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(IMG_WIDTH,IMG_HEIGHT),
    batch_size = 4,
    class_mode = 'categorical'
)
test_datagen = testa_datagen.flow_from_directory(
    test_data_dir,
    target_size=(IMG_WIDTH,IMG_HEIGHT),
    batch_size = 4,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 5021 images belonging to 9 classes.
# Found 717 images belonging to 9 classes.
# Found 1442 images belonging to 9 classes.

# %%
class_indices = train_generator.class_indices
print(class_indices)
# Out:
# {'ADI': 0, 'BACK': 1, 'DEB': 2, 'LYM': 3, 'MUC': 4, 'MUS': 5, 'NORM': 6, 'STR': 7, 'TUM': 8}

# %% [markdown]
# # **Number of images for each class in the training dataset**

# %%
# Count the number of images for each class in the training dataset
#classes = os.listdir(train_data_dir)
classes = [class_name for class_name in os.listdir(train_data_dir) if os.path.isdir(os.path.join(train_data_dir,class_name))]
for class_name in classes:
    class_path = os.path.join(train_data_dir, class_name)
    num_images = len(os.listdir(class_path))
    print(f"Class: {class_name}, Number of images: {num_images}")
# Out:
# Class: ADI, Number of images: 936
# Class: MUC, Number of images: 724
# Class: BACK, Number of images: 592
# Class: LYM, Number of images: 443
# Class: NORM, Number of images: 518
# Class: DEB, Number of images: 237
# Class: MUS, Number of images: 414
# Class: TUM, Number of images: 863
# Class: STR, Number of images: 294

# %% [markdown]
# # **Check the shape of the images in Train Generator**

# %%
# Get a batch of images and labels from the train_generator
batch = train_generator.__next__()

# Iterate through the batch to check image shapes
for i in range(len(batch[0])):
    img = batch[0][i]  # Image data
    label = batch[1][i]  # Image label
    
    # Get image shape and channels
    height, width, channels = img.shape
    
    # Display image shape and channels
    print(f"Image {i+1} - Shape: {width}x{height}x{channels}, Label: {label}")
# Out:
# Image 1 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 0. 0. 1.]
# Image 2 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 1. 0. 0.]
# Image 3 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 1. 0. 0.]
# Image 4 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 1. 0. 0. 0.]
# Image 5 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 0. 1. 0.]
# Image 6 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 0. 1. 0.]
# Image 7 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 0. 0. 1.]
# Image 8 - Shape: 224x224x3, Label: [0. 1. 0. 0. 0. 0. 0. 0. 0.]

# %% [markdown]
# # **Number of images for each class in the testing dataset**

# %%
# Count the number of images for each class in the testing dataset
classes = os.listdir(test_data_dir)
classes = [class_name for class_name in os.listdir(test_data_dir) if os.path.isdir(os.path.join(train_data_dir,class_name))]
for class_name in classes:
    class_path = os.path.join(test_data_dir, class_name)
    num_images = len(os.listdir(class_path))
    print(f"Class: {class_name}, Number of images: {num_images}")
# Out:
# Class: ADI, Number of images: 268
# Class: MUC, Number of images: 208
# Class: BACK, Number of images: 170
# Class: LYM, Number of images: 128
# Class: NORM, Number of images: 149
# Class: DEB, Number of images: 68
# Class: MUS, Number of images: 119
# Class: TUM, Number of images: 247
# Class: STR, Number of images: 85

# %% [markdown]
# # **Check the shape of the images in Test Generator**

# %%
# Get a batch of images and labels from the test_generator
batch = test_datagen.__next__()

# Iterate through the batch to check image shapes
for i in range(len(batch[0])):
    img = batch[0][i]  # Image data
    label = batch[1][i]  # Image label
    
    # Get image shape and channels
    height, width, channels = img.shape
    
    # Display image shape and channels
    print(f"Image {i+1} - Shape: {width}x{height}x{channels}, Label: {label}")
# Out:
# Image 1 - Shape: 224x224x3, Label: [1. 0. 0. 0. 0. 0. 0. 0. 0.]
# Image 2 - Shape: 224x224x3, Label: [1. 0. 0. 0. 0. 0. 0. 0. 0.]
# Image 3 - Shape: 224x224x3, Label: [1. 0. 0. 0. 0. 0. 0. 0. 0.]
# Image 4 - Shape: 224x224x3, Label: [1. 0. 0. 0. 0. 0. 0. 0. 0.]

# %% [markdown]
# # **Number of images for each class in the validation dataset**

# %%
# Count the number of images for each class in the testing dataset
#classes = os.listdir(validation_data_dir)
classes = [class_name for class_name in os.listdir(train_data_dir) if os.path.isdir(os.path.join(train_data_dir,class_name))]
for class_name in classes:
    class_path = os.path.join(validation_data_dir, class_name)
    num_images = len(os.listdir(class_path))
    print(f"Class: {class_name}, Number of images: {num_images}")
# Out:
# Class: ADI, Number of images: 134
# Class: MUC, Number of images: 103
# Class: BACK, Number of images: 85
# Class: LYM, Number of images: 63
# Class: NORM, Number of images: 74
# Class: DEB, Number of images: 34
# Class: MUS, Number of images: 59
# Class: TUM, Number of images: 123
# Class: STR, Number of images: 42

# %% [markdown]
# # **Check the shape of the images in Validation Generator**

# %%
# Get a batch of images and labels from the validation_generator
batch = val_datagen.__next__()

# Iterate through the batch to check image shapes
for i in range(len(batch[0])):
    img = batch[0][i]  # Image data
    label = batch[1][i]  # Image label
    
    # Get image shape and channels
    height, width, channels = img.shape
    
    # Display image shape and channels
    print(f"Image {i+1} - Shape: {width}x{height}x{channels}, Label: {label}")
# Out:
# Image 1 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 1. 0. 0.]
# Image 2 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 1. 0. 0.]
# Image 3 - Shape: 224x224x3, Label: [0. 0. 0. 0. 0. 0. 0. 0. 1.]
# Image 4 - Shape: 224x224x3, Label: [0. 1. 0. 0. 0. 0. 0. 0. 0.]

# %% [markdown]
# # **Check for GPU availability**

# %%
# Check for GPU availability
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT available")

# Set TensorFlow to use the GPU device
if tf.config.list_physical_devices('GPU'):
    tf.config.experimental.set_memory_growth(tf.config.list_physical_devices('GPU')[0], True)
    print("GPU device configured")
else:
    print("No GPU device found")
# Out:
# GPU is available
# GPU device configured

# %% [markdown]
# # **Model checkpoint**

# %%
from datetime import datetime
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,TensorBoard
model_dir = '/Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet'

if not os.path.exists(model_dir):
    os.makedirs(model_dir)

timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
checkpoint_filename = os.path.join(model_dir,f"model_{timestamp}.keras")

#create an early stopping callback
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=4,
    restore_best_weights = True,
    verbose=1
    
)

board_dir= "logs/densenet121/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensor_log = TensorBoard(
    log_dir = board_dir,
    histogram_freq=1,
    write_graph=True,
    write_images=False
)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filename,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor="val_accuracy",   # Monitor validation loss
                                                 mode="max",           # Save the model when validation loss is minimized
                                                 verbose=1)

# %%
print(checkpoint_filename)
# Out:
# /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras

# %% [markdown]
# # *Architecture*

# %%
from tensorflow.keras import models, layers, optimizers

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input
from tensorflow.keras.applications import MobileNetV3Large,EfficientNetV2B0
def create_model(summary=True):
    
    # apply transfer learning
    inputs = Input(shape=(224, 224, 3),name='input_layer')
    
    base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_tensor=inputs)
    base_model.trainable = False
    # base_model = EfficientNetV2B0(weights='imagenet', include_top=False, input_tensor=inputs)
    
    # add new classifier layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128,activation = 'relu')(x)
    output = Dense(9, activation='softmax')(x)  
    
    # define new model
    model = Model(inputs=inputs,outputs=output)
    
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    if summary:
        print(model.summary())
    return model

# %% [markdown]
# # **Model summary**

# %%
model = create_model()
# Out:
# 2026-01-26 19:35:48.995243: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2026-01-26 19:35:48.995290: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-01-26 19:35:48.995296: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2026-01-26 19:35:48.995792: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-01-26 19:35:48.996299: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_layer[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add (TFOp  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  Lambda)
#
#  re_lu (ReLU)                (None, 112, 112, 16)         0         ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 112, 112, 16)         0         ['re_lu[0][0]']
#  da)
#
#  multiply (Multiply)         (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (D  (None, 112, 112, 16)         144       ['multiply[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv/depthwise/Ba  (None, 112, 112, 16)         64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 16)         0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/project (Con  (None, 112, 112, 16)         256       ['re_lu_1[0][0]']
#  v2D)
#
#  expanded_conv/project/Batc  (None, 112, 112, 16)         64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv/Add (Add)     (None, 112, 112, 16)         0         ['multiply[0][0]',
#                                                                      'expanded_conv/project/BatchN
#                                                                     orm[0][0]']
#
#  expanded_conv_1/expand (Co  (None, 112, 112, 64)         1024      ['expanded_conv/Add[0][0]']
#  nv2D)
#
#  expanded_conv_1/expand/Bat  (None, 112, 112, 64)         256       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_2 (ReLU)              (None, 112, 112, 64)         0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 113, 113, 64)         0         ['re_lu_2[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 56, 56, 64)           576       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 56, 56, 64)           256       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_3 (ReLU)              (None, 56, 56, 64)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 56, 56, 24)           1536      ['re_lu_3[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_4 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 56, 56, 72)           648       ['re_lu_4[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 56, 56, 72)           288       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 56, 56, 24)           1728      ['re_lu_5[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 56, 56, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_6 (ReLU)              (None, 56, 56, 72)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 59, 59, 72)           0         ['re_lu_6[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 28, 28, 72)           1800      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_7 (ReLU)              (None, 28, 28, 72)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             0         ['re_lu_7[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             1752      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             1800      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 1, 1, 72)             0         ['expanded_conv_3/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_8 (ReLU)              (None, 1, 1, 72)             0         ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.math.multiply_1 (TFOpLa  (None, 1, 1, 72)             0         ['re_lu_8[0][0]']
#  mbda)
#
#  expanded_conv_3/squeeze_ex  (None, 28, 28, 72)           0         ['re_lu_7[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (C  (None, 28, 28, 40)           2880      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_9 (ReLU)              (None, 28, 28, 120)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_4/depthwise   (None, 28, 28, 120)          3000      ['re_lu_9[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_10 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_10[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 1, 1, 120)            0         ['expanded_conv_4/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_11 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  tf.math.multiply_2 (TFOpLa  (None, 1, 1, 120)            0         ['re_lu_11[0][0]']
#  mbda)
#
#  expanded_conv_4/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_10[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_12 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_5/depthwise   (None, 28, 28, 120)          3000      ['re_lu_12[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_13 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_13[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 1, 1, 120)            0         ['expanded_conv_5/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_14 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  tf.math.multiply_3 (TFOpLa  (None, 1, 1, 120)            0         ['re_lu_14[0][0]']
#  mbda)
#
#  expanded_conv_5/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_13[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 28, 28, 240)          9600      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 28, 28, 240)          960       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_4 (TF  (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_15 (ReLU)             (None, 28, 28, 240)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  tf.math.multiply_4 (TFOpLa  (None, 28, 28, 240)          0         ['re_lu_15[0][0]']
#  mbda)
#
#  multiply_1 (Multiply)       (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 29, 29, 240)          0         ['multiply_1[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_6/depthwise   (None, 14, 14, 240)          2160      ['expanded_conv_6/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_5 (TF  (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  tf.math.multiply_5 (TFOpLa  (None, 14, 14, 240)          0         ['re_lu_16[0][0]']
#  mbda)
#
#  multiply_2 (Multiply)       (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 80)           19200     ['multiply_2[0][0]']
#  onv2D)
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 200)          16000     ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 200)          800       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_6 (TF  (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_17 (ReLU)             (None, 14, 14, 200)          0         ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  tf.math.multiply_6 (TFOpLa  (None, 14, 14, 200)          0         ['re_lu_17[0][0]']
#  mbda)
#
#  multiply_3 (Multiply)       (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 200)          1800      ['multiply_3[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 200)          800       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_7 (TF  (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_18 (ReLU)             (None, 14, 14, 200)          0         ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  tf.math.multiply_7 (TFOpLa  (None, 14, 14, 200)          0         ['re_lu_18[0][0]']
#  mbda)
#
#  multiply_4 (Multiply)       (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (C  (None, 14, 14, 80)           16000     ['multiply_4[0][0]']
#  onv2D)
#
#  expanded_conv_7/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_6/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_7/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_8/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_7/Add[0][0]']
#  nv2D)
#
#  expanded_conv_8/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_8/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_8 (TF  (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  tf.math.multiply_8 (TFOpLa  (None, 14, 14, 184)          0         ['re_lu_19[0][0]']
#  mbda)
#
#  multiply_5 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise   (None, 14, 14, 184)          1656      ['multiply_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_8/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_8/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_9 (TF  (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_20 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  tf.math.multiply_9 (TFOpLa  (None, 14, 14, 184)          0         ['re_lu_20[0][0]']
#  mbda)
#
#  multiply_6 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (C  (None, 14, 14, 80)           14720     ['multiply_6[0][0]']
#  onv2D)
#
#  expanded_conv_8/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_8/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_8/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_7/Add[0][0]',
#                                                                      'expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_9/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_8/Add[0][0]']
#  nv2D)
#
#  expanded_conv_9/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_9/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_10 (T  (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_21 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.multiply_10 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_21[0][0]']
#  ambda)
#
#  multiply_7 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise   (None, 14, 14, 184)          1656      ['multiply_7[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_11 (T  (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_22 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  tf.math.multiply_11 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_22[0][0]']
#  ambda)
#
#  multiply_8 (Multiply)       (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (C  (None, 14, 14, 80)           14720     ['multiply_8[0][0]']
#  onv2D)
#
#  expanded_conv_9/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
# ...
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            24000     ['multiply_15[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_13/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_22 (T  (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_33 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_22[0][0
#                                                                     ]']
#
#  tf.math.multiply_22 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_33[0][0]']
#  ambda)
#
#  multiply_16 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_22[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_16[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_13/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_13/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_13/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_23 (T  (None, 1, 1, 960)            0         ['expanded_conv_13/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_34 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_23[0][0
#                                                                     ]']
#
#  tf.math.multiply_23 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_34[0][0]']
#  ambda)
#
#  expanded_conv_13/squeeze_e  (None, 7, 7, 960)            0         ['multiply_16[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_23[0][0]']
#
#  expanded_conv_13/project (  (None, 7, 7, 160)            153600    ['expanded_conv_13/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_13/project/B  (None, 7, 7, 160)            640       ['expanded_conv_13/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_13/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_12/project/Bat
#                                                                     chNorm[0][0]',
#                                                                      'expanded_conv_13/project/Bat
#                                                                     chNorm[0][0]']
#
#  expanded_conv_14/expand (C  (None, 7, 7, 960)            153600    ['expanded_conv_13/Add[0][0]']
#  onv2D)
#
#  expanded_conv_14/expand/Ba  (None, 7, 7, 960)            3840      ['expanded_conv_14/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.__operators__.add_24 (T  (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#  FOpLambda)                                                         hNorm[0][0]']
#
#  re_lu_35 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_24[0][0
#                                                                     ]']
#
#  tf.math.multiply_24 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_35[0][0]']
#  ambda)
#
#  multiply_17 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_24[0][0]']
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            24000     ['multiply_17[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_14/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_25 (T  (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_36 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_25[0][0
#                                                                     ]']
#
#  tf.math.multiply_25 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_36[0][0]']
#  ambda)
#
#  multiply_18 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_25[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_18[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_14/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_14/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_14/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_26 (T  (None, 1, 1, 960)            0         ['expanded_conv_14/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_37 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_26[0][0
#                                                                     ]']
#
#  tf.math.multiply_26 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_37[0][0]']
#  ambda)
#
#  expanded_conv_14/squeeze_e  (None, 7, 7, 960)            0         ['multiply_18[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_26[0][0]']
#
#  expanded_conv_14/project (  (None, 7, 7, 160)            153600    ['expanded_conv_14/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_14/project/B  (None, 7, 7, 160)            640       ['expanded_conv_14/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_14/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_13/Add[0][0]',
#                                                                      'expanded_conv_14/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 960)            153600    ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 960)            3840      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_27 (T  (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_38 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_27[0][0
#                                                                     ]']
#
#  tf.math.multiply_27 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_38[0][0]']
#  ambda)
#
#  multiply_19 (Multiply)      (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_27[0][0]']
#
#  global_average_pooling2d (  (None, 960)                  0         ['multiply_19[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)                  123008    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 9)                    1161      ['dense[0][0]']
#
# ==================================================================================================
# Total params: 3120521 (11.90 MB)
# Trainable params: 124169 (485.04 KB)
# Non-trainable params: 2996352 (11.43 MB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # **Training starts here**

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=val_datagen,
    callbacks=[cp_callback,early_stop,tensor_log]
    )
# Out:
# Epoch 1/20
# 2026-01-26 19:35:55.518831: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 628/628 [==============================] - ETA: 0s - loss: 0.6114 - accuracy: 0.8140
# 2026-01-26 19:36:30.079888: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.90377, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 44s 62ms/step - loss: 0.6114 - accuracy: 0.8140 - val_loss: 0.2897 - val_accuracy: 0.9038
# Epoch 2/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.1790 - accuracy: 0.9453
# Epoch 2: val_accuracy improved from 0.90377 to 0.95537, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 34s 55ms/step - loss: 0.1788 - accuracy: 0.9454 - val_loss: 0.1440 - val_accuracy: 0.9554
# Epoch 3/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9631
# Epoch 3: val_accuracy improved from 0.95537 to 0.96792, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 33s 53ms/step - loss: 0.1270 - accuracy: 0.9630 - val_loss: 0.1073 - val_accuracy: 0.9679
# Epoch 4/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0995 - accuracy: 0.9701
# Epoch 4: val_accuracy improved from 0.96792 to 0.97768, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0995 - accuracy: 0.9701 - val_loss: 0.0861 - val_accuracy: 0.9777
# Epoch 5/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9737
# Epoch 5: val_accuracy improved from 0.97768 to 0.97908, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0879 - accuracy: 0.9735 - val_loss: 0.0673 - val_accuracy: 0.9791
# Epoch 6/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0706 - accuracy: 0.9781
# Epoch 6: val_accuracy did not improve from 0.97908
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0707 - accuracy: 0.9779 - val_loss: 0.0634 - val_accuracy: 0.9777
# Epoch 7/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0651 - accuracy: 0.9795
# Epoch 7: val_accuracy improved from 0.97908 to 0.98047, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0651 - accuracy: 0.9795 - val_loss: 0.0588 - val_accuracy: 0.9805
# Epoch 8/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9814
# Epoch 8: val_accuracy improved from 0.98047 to 0.98466, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0624 - accuracy: 0.9815 - val_loss: 0.0481 - val_accuracy: 0.9847
# Epoch 9/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9843
# Epoch 9: val_accuracy did not improve from 0.98466
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0580 - accuracy: 0.9843 - val_loss: 0.0500 - val_accuracy: 0.9847
# Epoch 10/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0464 - accuracy: 0.9856
# Epoch 10: val_accuracy improved from 0.98466 to 0.98745, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0465 - accuracy: 0.9857 - val_loss: 0.0454 - val_accuracy: 0.9874
# Epoch 11/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9851
# Epoch 11: val_accuracy did not improve from 0.98745
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0490 - accuracy: 0.9851 - val_loss: 0.0409 - val_accuracy: 0.9874
# Epoch 12/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9836
# Epoch 12: val_accuracy did not improve from 0.98745
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0455 - accuracy: 0.9837 - val_loss: 0.0361 - val_accuracy: 0.9861
# Epoch 13/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9861
# Epoch 13: val_accuracy did not improve from 0.98745
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0432 - accuracy: 0.9861 - val_loss: 0.0319 - val_accuracy: 0.9874
# Epoch 14/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9862
# Epoch 14: val_accuracy improved from 0.98745 to 0.99024, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0443 - accuracy: 0.9863 - val_loss: 0.0321 - val_accuracy: 0.9902
# Epoch 15/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9877
# Epoch 15: val_accuracy did not improve from 0.99024
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0410 - accuracy: 0.9877 - val_loss: 0.0312 - val_accuracy: 0.9902
# Epoch 16/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9890
# Epoch 16: val_accuracy did not improve from 0.99024
# 628/628 [==============================] - 33s 52ms/step - loss: 0.0355 - accuracy: 0.9890 - val_loss: 0.0284 - val_accuracy: 0.9902
# Epoch 17/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9877
# Epoch 17: val_accuracy did not improve from 0.99024
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0371 - accuracy: 0.9877 - val_loss: 0.0345 - val_accuracy: 0.9888
# Epoch 18/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0362 - accuracy: 0.9880
# Epoch 18: val_accuracy improved from 0.99024 to 0.99303, saving model to /Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras
# 628/628 [==============================] - 34s 54ms/step - loss: 0.0362 - accuracy: 0.9881 - val_loss: 0.0257 - val_accuracy: 0.9930
# Epoch 19/20
# 628/628 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9910
# Epoch 19: val_accuracy did not improve from 0.99303
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0302 - accuracy: 0.9910 - val_loss: 0.0254 - val_accuracy: 0.9930
# Epoch 20/20
# 627/628 [============================>.] - ETA: 0s - loss: 0.0357 - accuracy: 0.9880
# Epoch 20: val_accuracy did not improve from 0.99303
# 628/628 [==============================] - 33s 53ms/step - loss: 0.0356 - accuracy: 0.9881 - val_loss: 0.0336 - val_accuracy: 0.9861

# %%
#Loading the model weights
from tensorflow.keras.models import load_model
model = create_model()
model.load_weights('/Users/tony/Documents/research_projects/mult_colon/model/keras_check/mobileNet/model_20260126-193545.keras')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]        0         []
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)          0         ['input_layer[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_28 (T  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_39 (ReLU)             (None, 112, 112, 16)         0         ['tf.__operators__.add_28[0][0
#                                                                     ]']
#
#  tf.math.multiply_28 (TFOpL  (None, 112, 112, 16)         0         ['re_lu_39[0][0]']
#  ambda)
#
#  multiply_20 (Multiply)      (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_28[0][0]']
#
#  expanded_conv/depthwise (D  (None, 112, 112, 16)         144       ['multiply_20[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv/depthwise/Ba  (None, 112, 112, 16)         64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_40 (ReLU)             (None, 112, 112, 16)         0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/project (Con  (None, 112, 112, 16)         256       ['re_lu_40[0][0]']
#  v2D)
#
#  expanded_conv/project/Batc  (None, 112, 112, 16)         64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv/Add (Add)     (None, 112, 112, 16)         0         ['multiply_20[0][0]',
#                                                                      'expanded_conv/project/BatchN
#                                                                     orm[0][0]']
#
#  expanded_conv_1/expand (Co  (None, 112, 112, 64)         1024      ['expanded_conv/Add[0][0]']
#  nv2D)
#
#  expanded_conv_1/expand/Bat  (None, 112, 112, 64)         256       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_41 (ReLU)             (None, 112, 112, 64)         0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 113, 113, 64)         0         ['re_lu_41[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 56, 56, 64)           576       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 56, 56, 64)           256       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_42 (ReLU)             (None, 56, 56, 64)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 56, 56, 24)           1536      ['re_lu_42[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_43 (ReLU)             (None, 56, 56, 72)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 56, 56, 72)           648       ['re_lu_43[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 56, 56, 72)           288       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_44 (ReLU)             (None, 56, 56, 72)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 56, 56, 24)           1728      ['re_lu_44[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 56, 56, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 56, 56, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 56, 56, 72)           1728      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_45 (ReLU)             (None, 56, 56, 72)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 59, 59, 72)           0         ['re_lu_45[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 28, 28, 72)           1800      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_46 (ReLU)             (None, 28, 28, 72)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             0         ['re_lu_46[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             1752      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             1800      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_29 (T  (None, 1, 1, 72)             0         ['expanded_conv_3/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_47 (ReLU)             (None, 1, 1, 72)             0         ['tf.__operators__.add_29[0][0
#                                                                     ]']
#
#  tf.math.multiply_29 (TFOpL  (None, 1, 1, 72)             0         ['re_lu_47[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, 28, 28, 72)           0         ['re_lu_46[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_29[0][0]']
#
#  expanded_conv_3/project (C  (None, 28, 28, 40)           2880      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_48 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_4/depthwise   (None, 28, 28, 120)          3000      ['re_lu_48[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_49 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_49[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_30 (T  (None, 1, 1, 120)            0         ['expanded_conv_4/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_50 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_30[0][0
#                                                                     ]']
#
#  tf.math.multiply_30 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_50[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_49[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_30[0][0]']
#
#  expanded_conv_4/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 28, 28, 120)          4800      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 28, 28, 120)          480       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_51 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_5/depthwise   (None, 28, 28, 120)          3000      ['re_lu_51[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 28, 28, 120)          480       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_52 (ReLU)             (None, 28, 28, 120)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_52[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_31 (T  (None, 1, 1, 120)            0         ['expanded_conv_5/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_53 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_31[0][0
#                                                                     ]']
#
#  tf.math.multiply_31 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_53[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 28, 28, 120)          0         ['re_lu_52[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_31[0][0]']
#
#  expanded_conv_5/project (C  (None, 28, 28, 40)           4800      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 28, 28, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 28, 28, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 28, 28, 240)          9600      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 28, 28, 240)          960       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_32 (T  (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_54 (ReLU)             (None, 28, 28, 240)          0         ['tf.__operators__.add_32[0][0
#                                                                     ]']
#
#  tf.math.multiply_32 (TFOpL  (None, 28, 28, 240)          0         ['re_lu_54[0][0]']
#  ambda)
#
#  multiply_21 (Multiply)      (None, 28, 28, 240)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_32[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 29, 29, 240)          0         ['multiply_21[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_6/depthwise   (None, 14, 14, 240)          2160      ['expanded_conv_6/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_33 (T  (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_55 (ReLU)             (None, 14, 14, 240)          0         ['tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  tf.math.multiply_33 (TFOpL  (None, 14, 14, 240)          0         ['re_lu_55[0][0]']
#  ambda)
#
#  multiply_22 (Multiply)      (None, 14, 14, 240)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_33[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 80)           19200     ['multiply_22[0][0]']
#  onv2D)
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 200)          16000     ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 200)          800       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_34 (T  (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_56 (ReLU)             (None, 14, 14, 200)          0         ['tf.__operators__.add_34[0][0
#                                                                     ]']
#
#  tf.math.multiply_34 (TFOpL  (None, 14, 14, 200)          0         ['re_lu_56[0][0]']
#  ambda)
#
#  multiply_23 (Multiply)      (None, 14, 14, 200)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_34[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 200)          1800      ['multiply_23[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 200)          800       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_35 (T  (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_57 (ReLU)             (None, 14, 14, 200)          0         ['tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  tf.math.multiply_35 (TFOpL  (None, 14, 14, 200)          0         ['re_lu_57[0][0]']
#  ambda)
#
#  multiply_24 (Multiply)      (None, 14, 14, 200)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_35[0][0]']
#
#  expanded_conv_7/project (C  (None, 14, 14, 80)           16000     ['multiply_24[0][0]']
#  onv2D)
#
#  expanded_conv_7/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_6/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_7/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_8/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_7/Add[0][0]']
#  nv2D)
#
#  expanded_conv_8/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_8/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_36 (T  (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_58 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_36[0][0
#                                                                     ]']
#
#  tf.math.multiply_36 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_58[0][0]']
#  ambda)
#
#  multiply_25 (Multiply)      (None, 14, 14, 184)          0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_36[0][0]']
#
#  expanded_conv_8/depthwise   (None, 14, 14, 184)          1656      ['multiply_25[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_8/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_8/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_37 (T  (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_59 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  tf.math.multiply_37 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_59[0][0]']
#  ambda)
#
#  multiply_26 (Multiply)      (None, 14, 14, 184)          0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_37[0][0]']
#
#  expanded_conv_8/project (C  (None, 14, 14, 80)           14720     ['multiply_26[0][0]']
#  onv2D)
#
#  expanded_conv_8/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_8/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_8/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_7/Add[0][0]',
#                                                                      'expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_9/expand (Co  (None, 14, 14, 184)          14720     ['expanded_conv_8/Add[0][0]']
#  nv2D)
#
#  expanded_conv_9/expand/Bat  (None, 14, 14, 184)          736       ['expanded_conv_9/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_38 (T  (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_60 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_38[0][0
#                                                                     ]']
#
#  tf.math.multiply_38 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_60[0][0]']
#  ambda)
#
#  multiply_27 (Multiply)      (None, 14, 14, 184)          0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_38[0][0]']
#
#  expanded_conv_9/depthwise   (None, 14, 14, 184)          1656      ['multiply_27[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 14, 14, 184)          736       ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_39 (T  (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_61 (ReLU)             (None, 14, 14, 184)          0         ['tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  tf.math.multiply_39 (TFOpL  (None, 14, 14, 184)          0         ['re_lu_61[0][0]']
#  ambda)
#
#  multiply_28 (Multiply)      (None, 14, 14, 184)          0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_39[0][0]']
#
#  expanded_conv_9/project (C  (None, 14, 14, 80)           14720     ['multiply_28[0][0]']
#  onv2D)
#
#  expanded_conv_9/project/Ba  (None, 14, 14, 80)           320       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 14, 14, 80)           0         ['expanded_conv_8/Add[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 14, 14, 480)          38400     ['expanded_conv_9/Add[0][0]']
#  onv2D)
# ...
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            24000     ['multiply_35[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_13/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_13/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_50 (T  (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_72 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_50[0][0
#                                                                     ]']
#
#  tf.math.multiply_50 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_72[0][0]']
#  ambda)
#
#  multiply_36 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_13/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_50[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_36[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_13/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_13/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_13/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_51 (T  (None, 1, 1, 960)            0         ['expanded_conv_13/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_73 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_51[0][0
#                                                                     ]']
#
#  tf.math.multiply_51 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_73[0][0]']
#  ambda)
#
#  expanded_conv_13/squeeze_e  (None, 7, 7, 960)            0         ['multiply_36[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_51[0][0]']
#
#  expanded_conv_13/project (  (None, 7, 7, 160)            153600    ['expanded_conv_13/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_13/project/B  (None, 7, 7, 160)            640       ['expanded_conv_13/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_13/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_12/project/Bat
#                                                                     chNorm[0][0]',
#                                                                      'expanded_conv_13/project/Bat
#                                                                     chNorm[0][0]']
#
#  expanded_conv_14/expand (C  (None, 7, 7, 960)            153600    ['expanded_conv_13/Add[0][0]']
#  onv2D)
#
#  expanded_conv_14/expand/Ba  (None, 7, 7, 960)            3840      ['expanded_conv_14/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.__operators__.add_52 (T  (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#  FOpLambda)                                                         hNorm[0][0]']
#
#  re_lu_74 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_52[0][0
#                                                                     ]']
#
#  tf.math.multiply_52 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_74[0][0]']
#  ambda)
#
#  multiply_37 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_14/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_52[0][0]']
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            24000     ['multiply_37[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_14/depthwise  (None, 7, 7, 960)            3840      ['expanded_conv_14/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_53 (T  (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_75 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_53[0][0
#                                                                     ]']
#
#  tf.math.multiply_53 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_75[0][0]']
#  ambda)
#
#  multiply_38 (Multiply)      (None, 7, 7, 960)            0         ['expanded_conv_14/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_53[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_38[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_14/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_14/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_14/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_54 (T  (None, 1, 1, 960)            0         ['expanded_conv_14/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_76 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_54[0][0
#                                                                     ]']
#
#  tf.math.multiply_54 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_76[0][0]']
#  ambda)
#
#  expanded_conv_14/squeeze_e  (None, 7, 7, 960)            0         ['multiply_38[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_54[0][0]']
#
#  expanded_conv_14/project (  (None, 7, 7, 160)            153600    ['expanded_conv_14/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_14/project/B  (None, 7, 7, 160)            640       ['expanded_conv_14/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_14/Add (Add)  (None, 7, 7, 160)            0         ['expanded_conv_13/Add[0][0]',
#                                                                      'expanded_conv_14/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 960)            153600    ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 960)            3840      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_55 (T  (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_77 (ReLU)             (None, 7, 7, 960)            0         ['tf.__operators__.add_55[0][0
#                                                                     ]']
#
#  tf.math.multiply_55 (TFOpL  (None, 7, 7, 960)            0         ['re_lu_77[0][0]']
#  ambda)
#
#  multiply_39 (Multiply)      (None, 7, 7, 960)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_55[0][0]']
#
#  global_average_pooling2d_1  (None, 960)                  0         ['multiply_39[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)                  123008    ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_3 (Dense)             (None, 9)                    1161      ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 3120521 (11.90 MB)
# Trainable params: 124169 (485.04 KB)
# Non-trainable params: 2996352 (11.43 MB)
# __________________________________________________________________________________________________
# None

# %%
import time
dummies_input = np.random.rand(1,224,224,3).astype(np.float32)

for _ in range(10):
    model.predict(dummies_input,verbose=0)

#time 
start = time.perf_counter()
model.predict(dummies_input,verbose=0)
end = time.perf_counter()
print(f"Inference time: {(end-start)*1000:.2f} ms")
# Out:
# 2026-01-26 23:44:42.061672: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Inference time: 39.27 ms

# %%
#Testing of the Image

results = model.evaluate(test_datagen)
print(f"Test Loss: {results[0]:.4f}")
print(f"Test Accuracy: {results[1]*100:.2f}%")

# For multiple metrics:
print("Metric Names:", model.metrics_names)  # Shows order of metrics
# Out:
# 2026-01-26 19:56:10.338342: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 361/361 [==============================] - 9s 22ms/step - loss: 0.0459 - accuracy: 0.9847
# Test Loss: 0.0459
# Test Accuracy: 98.47%
# Metric Names: ['loss', 'accuracy']

# %% [markdown]
# # Load dataset prototype

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from scipy.spatial.distance import cdist
from sklearn.metrics import accuracy_score
import random

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

base_path = '/Users/tony/Documents/research_projects/mult_colon/CRC_CFHCD_FIN_out'

#  Load Pre-Split Datasets 
def load_dataset_from_split(base_path, subset='train', target_size=(224, 224)):
    """Load images from pre-split train/test folders"""
    subset_path = os.path.join(base_path, subset)
    class_names = sorted(os.listdir(subset_path))
    images, labels = [], []
    
    for class_idx, class_name in enumerate(class_names):
        class_path = os.path.join(subset_path, class_name)
        for img_file in os.listdir(class_path):
            img = image.load_img(os.path.join(class_path, img_file), target_size=target_size)
            img_array = image.img_to_array(img)
            img_array = preprocess_input(img_array)  
            images.append(img_array)
            labels.append(class_idx)

    return np.array(images), np.array(labels), class_names

# Load your pre-split data
train_images, train_labels, class_names = load_dataset_from_split(base_path, 'train')
test_images, test_labels, _ = load_dataset_from_split(base_path, 'test')

# %%
#encoder
from tensorflow.keras.models import Model
import tensorflow as tf
import numpy as np
from scipy.spatial.distance import cdist

encoder = Model(
    inputs=model.input,
    outputs=model.layers[-2].output   # Dense(128)
)
encoder.trainable = False

# %%
#embedding computing

train_embeddings = encoder.predict(train_images, batch_size=32, verbose=1)
test_embeddings  = encoder.predict(test_images, batch_size=32, verbose=1)

# L2 normalization 
train_embeddings = tf.math.l2_normalize(train_embeddings, axis=1).numpy()
test_embeddings  = tf.math.l2_normalize(test_embeddings, axis=1).numpy()
# Out:
# 2026-01-26 20:08:04.710647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 47/47 [==============================] - 4s 54ms/step
# 12/12 [==============================] - 1s 89ms/step

# %%
def compute_distances(query_embeddings, prototypes, metric="euclidean"):
    if metric == "euclidean":
        return cdist(query_embeddings, prototypes, metric="euclidean")
    
    elif metric == "cosine":
        # cosine distance = 1 - cosine similarity
        return 1 - np.dot(query_embeddings, prototypes.T)
    
    else:
        raise ValueError("Metric must be 'euclidean' or 'cosine'")

# %%
def sample_episode(embeddings, labels, k_shot, n_query):
    support_idx, query_idx = [], []
    
    for cls in np.unique(labels):
        cls_idx = np.where(labels == cls)[0]
        selected = np.random.choice(cls_idx, k_shot + n_query, replace=False)
        support_idx.extend(selected[:k_shot])
        query_idx.extend(selected[k_shot:])
    
    return np.array(support_idx), np.array(query_idx)

# %%
import time
from sklearn.metrics import accuracy_score

def evaluate_fewshot(
    train_embeddings,
    train_labels,
    test_embeddings,
    test_labels,
    k_shot=5,
    n_query=15,
    n_episodes=100,
    metric="euclidean"
):
    accuracies = []
    distance_times = []

    for _ in range(n_episodes):
        # Support from TRAIN
        support_idx, _ = sample_episode(
            train_embeddings, train_labels, k_shot, 0
        )

        # Query from TEST
        _, query_idx = sample_episode(
            test_embeddings, test_labels, 0, n_query
        )

        # Prototypes
        prototypes = np.stack([
            np.mean(
                train_embeddings[support_idx][train_labels[support_idx] == cls],
                axis=0
            )
            for cls in np.unique(train_labels)
        ])

        # ---- distance timing ONLY ----
        start = time.perf_counter()

        distances = compute_distances(
            test_embeddings[query_idx],
            prototypes,
            metric=metric
        )

        end = time.perf_counter()
        distance_times.append((end - start) / len(query_idx))  # per-query time

        preds = np.argmin(distances, axis=1)
        acc = accuracy_score(test_labels[query_idx], preds)
        accuracies.append(acc)

    return (
        np.mean(accuracies),
        np.std(accuracies),
        np.mean(distance_times)
    )

# %%
print("\nFew-shot comparison (same encoder, same episodes):")

for metric in ["euclidean", "cosine"]:
    print(f"\nMetric: {metric.upper()}")
    for k in [1, 5, 10, 20]:
        mean_acc, std_acc, dist_time = evaluate_fewshot(
            train_embeddings,
            train_labels,
            test_embeddings,
            test_labels,
            k_shot=k,
            n_query=15,
            n_episodes=100,
            metric=metric
        )

        print(
            f"{k}-shot: {mean_acc:.2%} ± {std_acc:.2%} | "
            f"Dist time: {dist_time*1e6:.2f} µs/query"
        )
# Out:
# Few-shot comparison (same encoder, same episodes):
#
# Metric: EUCLIDEAN
# 1-shot: 84.93% ± 11.81% | Dist time: 1.35 µs/query
# 5-shot: 92.27% ± 4.32% | Dist time: 0.48 µs/query
# 10-shot: 93.93% ± 4.38% | Dist time: 0.44 µs/query
# 20-shot: 94.13% ± 3.75% | Dist time: 0.46 µs/query
#
# Metric: COSINE
# 1-shot: 84.17% ± 12.94% | Dist time: 0.62 µs/query
# 5-shot: 93.03% ± 4.83% | Dist time: 0.25 µs/query
# 10-shot: 93.17% ± 4.20% | Dist time: 1.50 µs/query
# 20-shot: 92.37% ± 4.09% | Dist time: 0.30 µs/query
